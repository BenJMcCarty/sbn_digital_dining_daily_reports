# %% [markdown]
# <h1>Table of Contents<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#Intro" data-toc-modified-id="Intro-1"><span class="toc-item-num">1&nbsp;&nbsp;</span>Intro</a></span></li><li><span><a href="#⭐-STAR-⭐" data-toc-modified-id="⭐-STAR-⭐-2"><span class="toc-item-num">2&nbsp;&nbsp;</span>⭐ STAR ⭐</a></span></li><li><span><a href="#📦-Imports" data-toc-modified-id="📦-Imports-3"><span class="toc-item-num">3&nbsp;&nbsp;</span>📦 Imports</a></span></li><li><span><a href="#💾-Read-Data" data-toc-modified-id="💾-Read-Data-4"><span class="toc-item-num">4&nbsp;&nbsp;</span>💾 Read Data</a></span></li><li><span><a href="#🧼-Cleaning" data-toc-modified-id="🧼-Cleaning-5"><span class="toc-item-num">5&nbsp;&nbsp;</span>🧼 Cleaning</a></span></li><li><span><a href="#🔨-Workflow" data-toc-modified-id="🔨-Workflow-6"><span class="toc-item-num">6&nbsp;&nbsp;</span>🔨 Workflow</a></span><ul class="toc-item"><li><span><a href="#Creating-Summary-for-Posting" data-toc-modified-id="Creating-Summary-for-Posting-6.1"><span class="toc-item-num">6.1&nbsp;&nbsp;</span>Creating Summary for Posting</a></span></li><li><span><a href="#Summarizing-the-Summary" data-toc-modified-id="Summarizing-the-Summary-6.2"><span class="toc-item-num">6.2&nbsp;&nbsp;</span>Summarizing the Summary</a></span></li></ul></li><li><span><a href="#👨‍💻-So-Far..." data-toc-modified-id="👨‍💻-So-Far...-7"><span class="toc-item-num">7&nbsp;&nbsp;</span>👨‍💻 So Far...</a></span></li><li><span><a href="#✔-Checkpoint---4.19.22" data-toc-modified-id="✔-Checkpoint---4.19.22-8"><span class="toc-item-num">8&nbsp;&nbsp;</span>✔ Checkpoint - 4.19.22</a></span></li><li><span><a href="#📄-Final-Script" data-toc-modified-id="📄-Final-Script-9"><span class="toc-item-num">9&nbsp;&nbsp;</span>📄 Final Script</a></span></li></ul></div>

# %% [markdown]
# # Intro

# %% [markdown]
# # ⭐ STAR ⭐

# %% [markdown]
# 🔎 **Situation** 🔍
#
# ---
#
# * NA uses DRR summary reports to post revenue in LS
# * I use report packet to review for DRR
#
# ---
#
# ⚠️ **Threat** ⚠️
#
# ---
#
# * **Pro:** clearly provide total sum amounts for audit to post directly
#
# * **Cons:**
#     * "Food" = "Food" + "Other"
#     * Discounts are ambiguous
#         * FBC vs. Assoc vs. others
#     * *LOTS* of unused rows/labels create visual confusion
#     * Not always clear to which XAC to post revenue/tax/tips
#     * Unusual/new/unused categories are not always accounted for
#
# All issues result in manual review of all transactions during the Daily reporting process.
#
# ---
#
#
# ⚒️ **Action** ⚒️
#
# ---
#
# **Create workflow to:**
#
# * *Read existing DD reports*
#
#
# * *Clean the report to isolate relevant details*
#
#
# * *Report any irregularities:*
#     * Any discounts or charges?
#     * Any new/non-standard MOPs?
#     * Report exact amounts to post to each LS XAC
#         * See below
#
# * Python Logging Documentation:
#     * References:
#         * [Real Python](https://realpython.com/python-logging/)
#         * [Python Docs](https://docs.python.org/3/howto/logging.html#logging-basic-tutorial)
# ---
#
# ---
#
# **End Goal:**
#
# ---
#
# > **Post these amounts in LightSpeed:**
#
# <!-- | |Dept | Rain 903 | IRD  | CC | Bar|
# | - | - | - | - | - | - |
# |**Sub-Dept** | |  |  |  |
# |Food | 1.00 | 1.00 | 1.00 | 1.00 |
# |Liquor | 2.00 | 2.00 | 2.00 | 2.00
# |Tax | 3.00 | 3.00 | 3.00 | 3.00
# |Gratuity | 4.00 | 4.00 | 4.00 | 4.00  -->
#
# |Dept| Food | Liquor | Tax  | Gratuity |
# | -  | -    | -      | -    | -        |
# | DR | 1.00 | 1.00   | 1.00 | 1.00     |
# | RS | 4.00 | 4.00   | 4.00 | 4.00     |
# | CC | 1.00 | 1.00   | 1.00 | 1.00     |
# | LB | 4.00 | 4.00   | 4.00 | 4.00     |
#
# ---
#
#  >**Investigate these amounts:**
#
#  | Item            | Amount |
#  | -               | - |
#  | Discount        | 1.00 |
#  | Charge          | 1.00 |
#  | $2 Tip - Coupon | 1.00 |
#
# ---
#
#
# 📋 **Result** 📋

# %% [markdown]
# # 📦 Imports

# %% [markdown]
# ---
#
# I will **use standard data reading/wrangling/EDA packages,** such as Numpy, Pandas, Matplotlib, and Seaborn, to prepare and review my data prior to generating the final report.
#
# Additionally, I will **import my own personal EDA module,** containing a selection of hand-written functions to make the EDA process a bit easier.
#
# Finally, I will **create two particular variables to help determine the source data:**
# 1. A Boolean variable controlling whether to use the reference files included in this repo (versus live/new reports).
# 2. A filepath as a string datatype to import the data.
#
# ---

# %%
## Importing Packages

import numpy as np
import pandas as pd
import bmcds.eda as eda
from functions.script import *

import matplotlib.pyplot as plt
import seaborn as sns

import logging

# from datetime import datetime, timedelta

pd.set_option('display.max_rows', None)
pd.set_option('display.float_format', '{:.2f}'.format)
# %matplotlib inline

# %%
## Importing and instantiating logger for future script useage.

logging.basicConfig(level=logging.INFO, format='%(asctime)s - %(message)s', 
                    datefmt='%d-%b-%y %H:%M:%S',filename='logs.log',filemode='a')

## Adapted from http://docs.python.org/howto/logging-cookbook.html#logging-cookbook

## Create logger and set level
logger = logging.getLogger('Report_Logs')
logger.setLevel(logging.INFO)

## Create log file
fh = logging.FileHandler('logs.log')
fh.setLevel(logging.INFO)

## Setting formatting
formatter = logging.Formatter('%(asctime)s - %(name)s - %(levelname)s - %(message)s')
fh.setFormatter(formatter)

logger.addHandler(fh)

# %% [markdown]
# # 💾 Read Data

# %%
## Specify file path

file_path = './data/02_25_2022_pc.xls'

# %%
## Read all columns from file (incl. empty columns)

df = pd.read_excel(file_path, skiprows = 2)
df
# Out:
#                              Bar Unnamed: 1  Dining Room Unnamed: 3  \
# 0                           Food     742.00          NaN     273.00
# 1                            NaN        NaN          NaN        NaN
# 2                       Beverage    1215.00          NaN       0.00
# 3                            NaN        NaN          NaN        NaN
# 4                          Other       0.00          NaN       0.00
# 5                            NaN        NaN          NaN        NaN
# 6                 Sales Subtotal    1957.00          NaN     273.00
# 7                            NaN        NaN          NaN        NaN
# 8                       Discount       0.00          NaN       0.00
# 9                            NaN        NaN          NaN        NaN
# 10                        Charge       0.00          NaN       0.00
# 11                           NaN        NaN          NaN        NaN
# 12              Total before tax    1957.00          NaN     273.00
# 13                           NaN        NaN          NaN        NaN
# 14                    MD Food 6%      44.52          NaN      16.38
# 15                           NaN        NaN          NaN        NaN
# 16                     MD Liq 9%     109.35          NaN       0.00
# 17                           NaN        NaN          NaN        NaN
# 18                          None       0.00          NaN       0.00
# 19                           NaN        NaN          NaN        NaN
# 20                          None       0.00          NaN       0.00
# 21                           NaN        NaN          NaN        NaN
# 22                  Tax Subtotal     153.87          NaN      16.38
# 23                           NaN        NaN          NaN        NaN
# 24              Receipt Rounding       0.00          NaN       0.00
# 25                           NaN        NaN          NaN        NaN
# 26                Total of check    2110.87          NaN     289.38
# 27                           NaN        NaN          NaN        NaN
# 28                                                   NaN
# 29                           NaN        NaN          NaN        NaN
# 30                 Tip collected     338.98          NaN      53.50
# 31                           NaN        NaN          NaN        NaN
# 32                   PaidIn - AR       0.00          NaN       0.00
# 33                           NaN        NaN          NaN        NaN
# 34              PaidIn - Debitek       0.00          NaN       0.00
# 35                           NaN        NaN          NaN        NaN
# 36    PaidIn - Gift Certificates       0.00          NaN       0.00
# 37                           NaN        NaN          NaN        NaN
# 38           Unadjusted receipts    2449.85          NaN     342.88
# 39                           NaN        NaN          NaN        NaN
# 40                                                   NaN
# 41                           NaN        NaN          NaN        NaN
# 42                  No of Covers      65.00          NaN      12.00
# 43                           NaN        NaN          NaN        NaN
# 44                  No of Checks         66          NaN         12
# 45                           NaN        NaN          NaN        NaN
# 46                     Avg cover      30.11          NaN      22.75
# 47                           NaN        NaN          NaN        NaN
# 48                     Avg check      29.65          NaN      22.75
# 49                           NaN        NaN          NaN        NaN
# 50                                                   NaN
# 51                           NaN        NaN          NaN        NaN
# 52                  ALL A&G CHRG      31.25          NaN      31.20
# 53                           NaN        NaN          NaN        NaN
# 54                   Room Charge     585.90          NaN     102.20
# 55                           NaN        NaN          NaN        NaN
# 56              American Express      91.79          NaN       0.00
# 57                           NaN        NaN          NaN        NaN
# 58                          Cash     240.84          NaN       0.00
# 59                           NaN        NaN          NaN        NaN
# 60                 Discover Card     134.73          NaN       0.00
# 61                           NaN        NaN          NaN        NaN
# 62                    MasterCard     334.45          NaN      58.32
# 63                           NaN        NaN          NaN        NaN
# 64                          Visa    1030.89          NaN     151.16
# 65                           NaN        NaN          NaN        NaN
# 66               $2 Tip - Coupon       0.00          NaN       0.00
# 67                           NaN        NaN          NaN        NaN
# 68                       PMS A&G       0.00          NaN       0.00
# 69                           NaN        NaN          NaN        NaN
# 70        Paper Gift Certificate       0.00          NaN       0.00
# 71                           NaN        NaN          NaN        NaN
# 72                       LevelUp       0.00          NaN       0.00
# 73                           NaN        NaN          NaN        NaN
# 74                         S & P       0.00          NaN       0.00
# 75                           NaN        NaN          NaN        NaN
# 76                  20% Discount       0.00          NaN       0.00
# 77                           NaN        NaN          NaN        NaN
# 78                   Bad Payment       0.00          NaN       0.00
# 79                           NaN        NaN          NaN        NaN
# 80              External Payment       0.00          NaN       0.00
# 81                           NaN        NaN          NaN        NaN
# 82                                                   NaN
# 83                           NaN        NaN          NaN        NaN
# 84           Unadjusted receipts    2449.85          NaN     342.88
# 85                           NaN        NaN          NaN        NaN
# 86               Total Paid Outs       0.00          NaN       0.00
# 87                           NaN        NaN          NaN        NaN
# 88                   Server bank       0.00          NaN       0.00
# 89                           NaN        NaN          NaN        NaN
# 90                    Total tips     338.98          NaN      53.50
# 91                           NaN        NaN          NaN        NaN
# 92       Server credit card fees       0.00          NaN       0.00
# 93                           NaN        NaN          NaN        NaN
# 94                      Net tips     338.98          NaN      53.50
# 95                           NaN        NaN          NaN        NaN
# 96                      Net Cash     -98.14          NaN     -53.50
# 97                           NaN        NaN          NaN        NaN
# 98      Other receipts turned in    2209.01          NaN     342.88
# 99                           NaN        NaN          NaN        NaN
# 100                 Server Drops       0.00          NaN       0.00
# 101                          NaN        NaN          NaN        NaN
# 102                    Turned in    2110.87          NaN     289.38
# 103                          NaN        NaN          NaN        NaN
# 104  Restaurant credit card fees       0.00          NaN       0.00
# 105                          NaN        NaN          NaN        NaN
# 106            Estimated deposit    2110.87          NaN     289.38
# 107                          NaN        NaN          NaN        NaN
# 108                                                  NaN
# 109                          NaN        NaN          NaN        NaN
# 110          Beginning NRS Total       0.00          NaN       0.00
# 111                          NaN        NaN          NaN        NaN
# 112               Total Receipts    2449.85          NaN     342.88
# 113                          NaN        NaN          NaN        NaN
# 114                    Discounts       0.00          NaN       0.00
# 115                          NaN        NaN          NaN        NaN
# 116                     Paid Ins       0.00          NaN       0.00
# 117                          NaN        NaN          NaN        NaN
# 118                  Gross Total    2449.85          NaN     342.88
# 119                          NaN        NaN          NaN        NaN
# 120                    NRS Total    2449.85          NaN     342.88
# 121                          NaN        NaN          NaN        NaN
# 122                          NaN        NaN          NaN        NaN
# 123                          NaN        NaN          NaN        NaN
# 124                          NaN        NaN          NaN        NaN
# 125        *** End of Report ***        NaN          NaN        NaN
#
#      Room Service Unnamed: 5  Starbucks Unnamed: 7  Page Total Unnamed: 9
# 0             NaN      62.00        NaN     247.65         NaN    1324.65
# 1             NaN        NaN        NaN        NaN         NaN        NaN
# 2             NaN       0.00        NaN       0.00         NaN    1215.00
# 3             NaN        NaN        NaN        NaN         NaN        NaN
# 4             NaN      20.00        NaN      16.25         NaN      36.25
# 5             NaN        NaN        NaN        NaN         NaN        NaN
# 6             NaN      82.00        NaN     263.90         NaN    2575.90
# 7             NaN        NaN        NaN        NaN         NaN        NaN
# 8             NaN       0.00        NaN       0.00         NaN       0.00
# 9             NaN        NaN        NaN        NaN         NaN        NaN
# 10            NaN       0.00        NaN       0.00         NaN       0.00
# 11            NaN        NaN        NaN        NaN         NaN        NaN
# 12            NaN      82.00        NaN     263.90         NaN    2575.90
# 13            NaN        NaN        NaN        NaN         NaN        NaN
# 14            NaN       3.72        NaN      16.04         NaN      80.66
# 15            NaN        NaN        NaN        NaN         NaN        NaN
# 16            NaN       0.00        NaN       0.00         NaN     109.35
# 17            NaN        NaN        NaN        NaN         NaN        NaN
# 18            NaN       0.00        NaN       0.00         NaN       0.00
# 19            NaN        NaN        NaN        NaN         NaN        NaN
# 20            NaN       0.00        NaN       0.00         NaN       0.00
# 21            NaN        NaN        NaN        NaN         NaN        NaN
# 22            NaN       3.72        NaN      16.04         NaN     190.01
# 23            NaN        NaN        NaN        NaN         NaN        NaN
# 24            NaN       0.00        NaN       0.00         NaN       0.00
# 25            NaN        NaN        NaN        NaN         NaN        NaN
# 26            NaN      85.72        NaN     279.94         NaN    2765.91
# 27            NaN        NaN        NaN        NaN         NaN        NaN
# 28            NaN                   NaN                    NaN
# 29            NaN        NaN        NaN        NaN         NaN        NaN
# 30            NaN      27.40        NaN      26.00         NaN     445.88
# 31            NaN        NaN        NaN        NaN         NaN        NaN
# 32            NaN       0.00        NaN       0.00         NaN       0.00
# 33            NaN        NaN        NaN        NaN         NaN        NaN
# 34            NaN       0.00        NaN       0.00         NaN       0.00
# 35            NaN        NaN        NaN        NaN         NaN        NaN
# 36            NaN       0.00        NaN       0.00         NaN       0.00
# 37            NaN        NaN        NaN        NaN         NaN        NaN
# 38            NaN     113.12        NaN     305.94         NaN    3211.79
# 39            NaN        NaN        NaN        NaN         NaN        NaN
# 40            NaN                   NaN                    NaN
# 41            NaN        NaN        NaN        NaN         NaN        NaN
# 42            NaN       4.00        NaN      43.00         NaN     124.00
# 43            NaN        NaN        NaN        NaN         NaN        NaN
# 44            NaN          4        NaN         43         NaN        125
# 45            NaN        NaN        NaN        NaN         NaN        NaN
# 46            NaN      20.50        NaN       6.14         NaN      20.77
# 47            NaN        NaN        NaN        NaN         NaN        NaN
# 48            NaN      20.50        NaN       6.14         NaN      20.61
# 49            NaN        NaN        NaN        NaN         NaN        NaN
# 50            NaN                   NaN                    NaN
# 51            NaN        NaN        NaN        NaN         NaN        NaN
# 52            NaN       0.00        NaN       0.00         NaN      62.45
# 53            NaN        NaN        NaN        NaN         NaN        NaN
# 54            NaN      70.88        NaN      46.80         NaN     805.78
# 55            NaN        NaN        NaN        NaN         NaN        NaN
# 56            NaN       0.00        NaN      10.22         NaN     102.01
# 57            NaN        NaN        NaN        NaN         NaN        NaN
# 58            NaN       0.00        NaN      35.60         NaN     276.44
# 59            NaN        NaN        NaN        NaN         NaN        NaN
# 60            NaN       0.00        NaN       0.00         NaN     134.73
# 61            NaN        NaN        NaN        NaN         NaN        NaN
# 62            NaN       0.00        NaN      31.38         NaN     424.15
# 63            NaN        NaN        NaN        NaN         NaN        NaN
# 64            NaN      42.24        NaN     181.94         NaN    1406.23
# 65            NaN        NaN        NaN        NaN         NaN        NaN
# 66            NaN       0.00        NaN       0.00         NaN       0.00
# 67            NaN        NaN        NaN        NaN         NaN        NaN
# 68            NaN       0.00        NaN       0.00         NaN       0.00
# 69            NaN        NaN        NaN        NaN         NaN        NaN
# 70            NaN       0.00        NaN       0.00         NaN       0.00
# 71            NaN        NaN        NaN        NaN         NaN        NaN
# 72            NaN       0.00        NaN       0.00         NaN       0.00
# 73            NaN        NaN        NaN        NaN         NaN        NaN
# 74            NaN       0.00        NaN       0.00         NaN       0.00
# 75            NaN        NaN        NaN        NaN         NaN        NaN
# 76            NaN       0.00        NaN       0.00         NaN       0.00
# 77            NaN        NaN        NaN        NaN         NaN        NaN
# 78            NaN       0.00        NaN       0.00         NaN       0.00
# 79            NaN        NaN        NaN        NaN         NaN        NaN
# 80            NaN       0.00        NaN       0.00         NaN       0.00
# 81            NaN        NaN        NaN        NaN         NaN        NaN
# 82            NaN                   NaN                    NaN
# 83            NaN        NaN        NaN        NaN         NaN        NaN
# 84            NaN     113.12        NaN     305.94         NaN    3211.79
# 85            NaN        NaN        NaN        NaN         NaN        NaN
# 86            NaN       0.00        NaN       0.00         NaN       0.00
# 87            NaN        NaN        NaN        NaN         NaN        NaN
# 88            NaN       0.00        NaN       0.00         NaN       0.00
# 89            NaN        NaN        NaN        NaN         NaN        NaN
# 90            NaN      27.40        NaN      26.00         NaN     445.88
# 91            NaN        NaN        NaN        NaN         NaN        NaN
# 92            NaN       0.00        NaN       0.00         NaN       0.00
# 93            NaN        NaN        NaN        NaN         NaN        NaN
# 94            NaN      27.40        NaN      26.00         NaN     445.88
# 95            NaN        NaN        NaN        NaN         NaN        NaN
# 96            NaN     -27.40        NaN       9.60         NaN    -169.44
# 97            NaN        NaN        NaN        NaN         NaN        NaN
# 98            NaN     113.12        NaN     270.34         NaN    2935.35
# 99            NaN        NaN        NaN        NaN         NaN        NaN
# 100           NaN       0.00        NaN       0.00         NaN       0.00
# 101           NaN        NaN        NaN        NaN         NaN        NaN
# 102           NaN      85.72        NaN     279.94         NaN    2765.91
# 103           NaN        NaN        NaN        NaN         NaN        NaN
# 104           NaN       0.00        NaN       0.00         NaN       0.00
# 105           NaN        NaN        NaN        NaN         NaN        NaN
# 106           NaN      85.72        NaN     279.94         NaN    2765.91
# 107           NaN        NaN        NaN        NaN         NaN        NaN
# 108           NaN                   NaN                    NaN
# 109           NaN        NaN        NaN        NaN         NaN        NaN
# 110           NaN       0.00        NaN       0.00         NaN       0.00
# 111           NaN        NaN        NaN        NaN         NaN        NaN
# 112           NaN     113.12        NaN     305.94         NaN    3211.79
# 113           NaN        NaN        NaN        NaN         NaN        NaN
# 114           NaN       0.00        NaN       0.00         NaN       0.00
# 115           NaN        NaN        NaN        NaN         NaN        NaN
# 116           NaN       0.00        NaN       0.00         NaN       0.00
# 117           NaN        NaN        NaN        NaN         NaN        NaN
# 118           NaN     113.12        NaN     305.94         NaN    3211.79
# 119           NaN        NaN        NaN        NaN         NaN        NaN
# 120           NaN     113.12        NaN     305.94         NaN    3211.79
# 121           NaN        NaN        NaN        NaN         NaN        NaN
# 122           NaN        NaN        NaN        NaN         NaN        NaN
# 123           NaN        NaN        NaN        NaN         NaN        NaN
# 124           NaN        NaN        NaN        NaN         NaN        NaN
# 125           NaN        NaN        NaN        NaN         NaN        NaN

# %% [markdown]
# # 🧼 Cleaning

# %% [markdown]
# ---
#
# I imported the data into a dataframe and immediately see that I will need to fix the alignment of my column names.
#
# Additionally, there are several "Unnamed" columns (representing empty, unlabeled columns generated as part of the report). Knowing those columns are empty, I will drop those as well.
#
# ---

# %%
## Shifting label names one to the right and drop extra column

df.columns = ['Label', *df.columns[:-1]]
df
# Out:
#                            Label      Bar  Unnamed: 1 Dining Room  Unnamed: 3  \
# 0                           Food   742.00         NaN      273.00         NaN
# 1                            NaN      NaN         NaN         NaN         NaN
# 2                       Beverage  1215.00         NaN        0.00         NaN
# 3                            NaN      NaN         NaN         NaN         NaN
# 4                          Other     0.00         NaN        0.00         NaN
# 5                            NaN      NaN         NaN         NaN         NaN
# 6                 Sales Subtotal  1957.00         NaN      273.00         NaN
# 7                            NaN      NaN         NaN         NaN         NaN
# 8                       Discount     0.00         NaN        0.00         NaN
# 9                            NaN      NaN         NaN         NaN         NaN
# 10                        Charge     0.00         NaN        0.00         NaN
# 11                           NaN      NaN         NaN         NaN         NaN
# 12              Total before tax  1957.00         NaN      273.00         NaN
# 13                           NaN      NaN         NaN         NaN         NaN
# 14                    MD Food 6%    44.52         NaN       16.38         NaN
# 15                           NaN      NaN         NaN         NaN         NaN
# 16                     MD Liq 9%   109.35         NaN        0.00         NaN
# 17                           NaN      NaN         NaN         NaN         NaN
# 18                          None     0.00         NaN        0.00         NaN
# 19                           NaN      NaN         NaN         NaN         NaN
# 20                          None     0.00         NaN        0.00         NaN
# 21                           NaN      NaN         NaN         NaN         NaN
# 22                  Tax Subtotal   153.87         NaN       16.38         NaN
# 23                           NaN      NaN         NaN         NaN         NaN
# 24              Receipt Rounding     0.00         NaN        0.00         NaN
# 25                           NaN      NaN         NaN         NaN         NaN
# 26                Total of check  2110.87         NaN      289.38         NaN
# 27                           NaN      NaN         NaN         NaN         NaN
# 28                                                NaN                     NaN
# 29                           NaN      NaN         NaN         NaN         NaN
# 30                 Tip collected   338.98         NaN       53.50         NaN
# 31                           NaN      NaN         NaN         NaN         NaN
# 32                   PaidIn - AR     0.00         NaN        0.00         NaN
# 33                           NaN      NaN         NaN         NaN         NaN
# 34              PaidIn - Debitek     0.00         NaN        0.00         NaN
# 35                           NaN      NaN         NaN         NaN         NaN
# 36    PaidIn - Gift Certificates     0.00         NaN        0.00         NaN
# 37                           NaN      NaN         NaN         NaN         NaN
# 38           Unadjusted receipts  2449.85         NaN      342.88         NaN
# 39                           NaN      NaN         NaN         NaN         NaN
# 40                                                NaN                     NaN
# 41                           NaN      NaN         NaN         NaN         NaN
# 42                  No of Covers    65.00         NaN       12.00         NaN
# 43                           NaN      NaN         NaN         NaN         NaN
# 44                  No of Checks       66         NaN          12         NaN
# 45                           NaN      NaN         NaN         NaN         NaN
# 46                     Avg cover    30.11         NaN       22.75         NaN
# 47                           NaN      NaN         NaN         NaN         NaN
# 48                     Avg check    29.65         NaN       22.75         NaN
# 49                           NaN      NaN         NaN         NaN         NaN
# 50                                                NaN                     NaN
# 51                           NaN      NaN         NaN         NaN         NaN
# 52                  ALL A&G CHRG    31.25         NaN       31.20         NaN
# 53                           NaN      NaN         NaN         NaN         NaN
# 54                   Room Charge   585.90         NaN      102.20         NaN
# 55                           NaN      NaN         NaN         NaN         NaN
# 56              American Express    91.79         NaN        0.00         NaN
# 57                           NaN      NaN         NaN         NaN         NaN
# 58                          Cash   240.84         NaN        0.00         NaN
# 59                           NaN      NaN         NaN         NaN         NaN
# 60                 Discover Card   134.73         NaN        0.00         NaN
# 61                           NaN      NaN         NaN         NaN         NaN
# 62                    MasterCard   334.45         NaN       58.32         NaN
# 63                           NaN      NaN         NaN         NaN         NaN
# 64                          Visa  1030.89         NaN      151.16         NaN
# 65                           NaN      NaN         NaN         NaN         NaN
# 66               $2 Tip - Coupon     0.00         NaN        0.00         NaN
# 67                           NaN      NaN         NaN         NaN         NaN
# 68                       PMS A&G     0.00         NaN        0.00         NaN
# 69                           NaN      NaN         NaN         NaN         NaN
# 70        Paper Gift Certificate     0.00         NaN        0.00         NaN
# 71                           NaN      NaN         NaN         NaN         NaN
# 72                       LevelUp     0.00         NaN        0.00         NaN
# 73                           NaN      NaN         NaN         NaN         NaN
# 74                         S & P     0.00         NaN        0.00         NaN
# 75                           NaN      NaN         NaN         NaN         NaN
# 76                  20% Discount     0.00         NaN        0.00         NaN
# 77                           NaN      NaN         NaN         NaN         NaN
# 78                   Bad Payment     0.00         NaN        0.00         NaN
# 79                           NaN      NaN         NaN         NaN         NaN
# 80              External Payment     0.00         NaN        0.00         NaN
# 81                           NaN      NaN         NaN         NaN         NaN
# 82                                                NaN                     NaN
# 83                           NaN      NaN         NaN         NaN         NaN
# 84           Unadjusted receipts  2449.85         NaN      342.88         NaN
# 85                           NaN      NaN         NaN         NaN         NaN
# 86               Total Paid Outs     0.00         NaN        0.00         NaN
# 87                           NaN      NaN         NaN         NaN         NaN
# 88                   Server bank     0.00         NaN        0.00         NaN
# 89                           NaN      NaN         NaN         NaN         NaN
# 90                    Total tips   338.98         NaN       53.50         NaN
# 91                           NaN      NaN         NaN         NaN         NaN
# 92       Server credit card fees     0.00         NaN        0.00         NaN
# 93                           NaN      NaN         NaN         NaN         NaN
# 94                      Net tips   338.98         NaN       53.50         NaN
# 95                           NaN      NaN         NaN         NaN         NaN
# 96                      Net Cash   -98.14         NaN      -53.50         NaN
# 97                           NaN      NaN         NaN         NaN         NaN
# 98      Other receipts turned in  2209.01         NaN      342.88         NaN
# 99                           NaN      NaN         NaN         NaN         NaN
# 100                 Server Drops     0.00         NaN        0.00         NaN
# 101                          NaN      NaN         NaN         NaN         NaN
# 102                    Turned in  2110.87         NaN      289.38         NaN
# 103                          NaN      NaN         NaN         NaN         NaN
# 104  Restaurant credit card fees     0.00         NaN        0.00         NaN
# 105                          NaN      NaN         NaN         NaN         NaN
# 106            Estimated deposit  2110.87         NaN      289.38         NaN
# 107                          NaN      NaN         NaN         NaN         NaN
# 108                                               NaN                     NaN
# 109                          NaN      NaN         NaN         NaN         NaN
# 110          Beginning NRS Total     0.00         NaN        0.00         NaN
# 111                          NaN      NaN         NaN         NaN         NaN
# 112               Total Receipts  2449.85         NaN      342.88         NaN
# 113                          NaN      NaN         NaN         NaN         NaN
# 114                    Discounts     0.00         NaN        0.00         NaN
# 115                          NaN      NaN         NaN         NaN         NaN
# 116                     Paid Ins     0.00         NaN        0.00         NaN
# 117                          NaN      NaN         NaN         NaN         NaN
# 118                  Gross Total  2449.85         NaN      342.88         NaN
# 119                          NaN      NaN         NaN         NaN         NaN
# 120                    NRS Total  2449.85         NaN      342.88         NaN
# 121                          NaN      NaN         NaN         NaN         NaN
# 122                          NaN      NaN         NaN         NaN         NaN
# 123                          NaN      NaN         NaN         NaN         NaN
# 124                          NaN      NaN         NaN         NaN         NaN
# 125        *** End of Report ***      NaN         NaN         NaN         NaN
#
#     Room Service  Unnamed: 5 Starbucks  Unnamed: 7 Page Total
# 0          62.00         NaN    247.65         NaN    1324.65
# 1            NaN         NaN       NaN         NaN        NaN
# 2           0.00         NaN      0.00         NaN    1215.00
# 3            NaN         NaN       NaN         NaN        NaN
# 4          20.00         NaN     16.25         NaN      36.25
# 5            NaN         NaN       NaN         NaN        NaN
# 6          82.00         NaN    263.90         NaN    2575.90
# 7            NaN         NaN       NaN         NaN        NaN
# 8           0.00         NaN      0.00         NaN       0.00
# 9            NaN         NaN       NaN         NaN        NaN
# 10          0.00         NaN      0.00         NaN       0.00
# 11           NaN         NaN       NaN         NaN        NaN
# 12         82.00         NaN    263.90         NaN    2575.90
# 13           NaN         NaN       NaN         NaN        NaN
# 14          3.72         NaN     16.04         NaN      80.66
# 15           NaN         NaN       NaN         NaN        NaN
# 16          0.00         NaN      0.00         NaN     109.35
# 17           NaN         NaN       NaN         NaN        NaN
# 18          0.00         NaN      0.00         NaN       0.00
# 19           NaN         NaN       NaN         NaN        NaN
# 20          0.00         NaN      0.00         NaN       0.00
# 21           NaN         NaN       NaN         NaN        NaN
# 22          3.72         NaN     16.04         NaN     190.01
# 23           NaN         NaN       NaN         NaN        NaN
# 24          0.00         NaN      0.00         NaN       0.00
# 25           NaN         NaN       NaN         NaN        NaN
# 26         85.72         NaN    279.94         NaN    2765.91
# 27           NaN         NaN       NaN         NaN        NaN
# 28                       NaN                   NaN
# 29           NaN         NaN       NaN         NaN        NaN
# 30         27.40         NaN     26.00         NaN     445.88
# 31           NaN         NaN       NaN         NaN        NaN
# 32          0.00         NaN      0.00         NaN       0.00
# 33           NaN         NaN       NaN         NaN        NaN
# 34          0.00         NaN      0.00         NaN       0.00
# 35           NaN         NaN       NaN         NaN        NaN
# 36          0.00         NaN      0.00         NaN       0.00
# 37           NaN         NaN       NaN         NaN        NaN
# 38        113.12         NaN    305.94         NaN    3211.79
# 39           NaN         NaN       NaN         NaN        NaN
# 40                       NaN                   NaN
# 41           NaN         NaN       NaN         NaN        NaN
# 42          4.00         NaN     43.00         NaN     124.00
# 43           NaN         NaN       NaN         NaN        NaN
# 44             4         NaN        43         NaN        125
# 45           NaN         NaN       NaN         NaN        NaN
# 46         20.50         NaN      6.14         NaN      20.77
# 47           NaN         NaN       NaN         NaN        NaN
# 48         20.50         NaN      6.14         NaN      20.61
# 49           NaN         NaN       NaN         NaN        NaN
# 50                       NaN                   NaN
# 51           NaN         NaN       NaN         NaN        NaN
# 52          0.00         NaN      0.00         NaN      62.45
# 53           NaN         NaN       NaN         NaN        NaN
# 54         70.88         NaN     46.80         NaN     805.78
# 55           NaN         NaN       NaN         NaN        NaN
# 56          0.00         NaN     10.22         NaN     102.01
# 57           NaN         NaN       NaN         NaN        NaN
# 58          0.00         NaN     35.60         NaN     276.44
# 59           NaN         NaN       NaN         NaN        NaN
# 60          0.00         NaN      0.00         NaN     134.73
# 61           NaN         NaN       NaN         NaN        NaN
# 62          0.00         NaN     31.38         NaN     424.15
# 63           NaN         NaN       NaN         NaN        NaN
# 64         42.24         NaN    181.94         NaN    1406.23
# 65           NaN         NaN       NaN         NaN        NaN
# 66          0.00         NaN      0.00         NaN       0.00
# 67           NaN         NaN       NaN         NaN        NaN
# 68          0.00         NaN      0.00         NaN       0.00
# 69           NaN         NaN       NaN         NaN        NaN
# 70          0.00         NaN      0.00         NaN       0.00
# 71           NaN         NaN       NaN         NaN        NaN
# 72          0.00         NaN      0.00         NaN       0.00
# 73           NaN         NaN       NaN         NaN        NaN
# 74          0.00         NaN      0.00         NaN       0.00
# 75           NaN         NaN       NaN         NaN        NaN
# 76          0.00         NaN      0.00         NaN       0.00
# 77           NaN         NaN       NaN         NaN        NaN
# 78          0.00         NaN      0.00         NaN       0.00
# 79           NaN         NaN       NaN         NaN        NaN
# 80          0.00         NaN      0.00         NaN       0.00
# 81           NaN         NaN       NaN         NaN        NaN
# 82                       NaN                   NaN
# 83           NaN         NaN       NaN         NaN        NaN
# 84        113.12         NaN    305.94         NaN    3211.79
# 85           NaN         NaN       NaN         NaN        NaN
# 86          0.00         NaN      0.00         NaN       0.00
# 87           NaN         NaN       NaN         NaN        NaN
# 88          0.00         NaN      0.00         NaN       0.00
# 89           NaN         NaN       NaN         NaN        NaN
# 90         27.40         NaN     26.00         NaN     445.88
# 91           NaN         NaN       NaN         NaN        NaN
# 92          0.00         NaN      0.00         NaN       0.00
# 93           NaN         NaN       NaN         NaN        NaN
# 94         27.40         NaN     26.00         NaN     445.88
# 95           NaN         NaN       NaN         NaN        NaN
# 96        -27.40         NaN      9.60         NaN    -169.44
# 97           NaN         NaN       NaN         NaN        NaN
# 98        113.12         NaN    270.34         NaN    2935.35
# 99           NaN         NaN       NaN         NaN        NaN
# 100         0.00         NaN      0.00         NaN       0.00
# 101          NaN         NaN       NaN         NaN        NaN
# 102        85.72         NaN    279.94         NaN    2765.91
# 103          NaN         NaN       NaN         NaN        NaN
# 104         0.00         NaN      0.00         NaN       0.00
# 105          NaN         NaN       NaN         NaN        NaN
# 106        85.72         NaN    279.94         NaN    2765.91
# 107          NaN         NaN       NaN         NaN        NaN
# 108                      NaN                   NaN
# 109          NaN         NaN       NaN         NaN        NaN
# 110         0.00         NaN      0.00         NaN       0.00
# 111          NaN         NaN       NaN         NaN        NaN
# 112       113.12         NaN    305.94         NaN    3211.79
# 113          NaN         NaN       NaN         NaN        NaN
# 114         0.00         NaN      0.00         NaN       0.00
# 115          NaN         NaN       NaN         NaN        NaN
# 116         0.00         NaN      0.00         NaN       0.00
# 117          NaN         NaN       NaN         NaN        NaN
# 118       113.12         NaN    305.94         NaN    3211.79
# 119          NaN         NaN       NaN         NaN        NaN
# 120       113.12         NaN    305.94         NaN    3211.79
# 121          NaN         NaN       NaN         NaN        NaN
# 122          NaN         NaN       NaN         NaN        NaN
# 123          NaN         NaN       NaN         NaN        NaN
# 124          NaN         NaN       NaN         NaN        NaN
# 125          NaN         NaN       NaN         NaN        NaN

# %%
## Creating list of columns to keep/drop

col_labels = ['Label', 'Bar', 'Dining Room', 'Room Service', 'Starbucks']
drop_cols = []

for col in df.columns:
    if col not in col_labels:
        drop_cols.append(col)
        
drop_cols
# Out:
# ['Unnamed: 1', 'Unnamed: 3', 'Unnamed: 5', 'Unnamed: 7', 'Page Total']

# %%
## Dropping columns not representing an outlet

df = df.drop(columns = drop_cols)
df
# Out:
#                            Label      Bar Dining Room Room Service Starbucks
# 0                           Food   742.00      273.00        62.00    247.65
# 1                            NaN      NaN         NaN          NaN       NaN
# 2                       Beverage  1215.00        0.00         0.00      0.00
# 3                            NaN      NaN         NaN          NaN       NaN
# 4                          Other     0.00        0.00        20.00     16.25
# 5                            NaN      NaN         NaN          NaN       NaN
# 6                 Sales Subtotal  1957.00      273.00        82.00    263.90
# 7                            NaN      NaN         NaN          NaN       NaN
# 8                       Discount     0.00        0.00         0.00      0.00
# 9                            NaN      NaN         NaN          NaN       NaN
# 10                        Charge     0.00        0.00         0.00      0.00
# 11                           NaN      NaN         NaN          NaN       NaN
# 12              Total before tax  1957.00      273.00        82.00    263.90
# 13                           NaN      NaN         NaN          NaN       NaN
# 14                    MD Food 6%    44.52       16.38         3.72     16.04
# 15                           NaN      NaN         NaN          NaN       NaN
# 16                     MD Liq 9%   109.35        0.00         0.00      0.00
# 17                           NaN      NaN         NaN          NaN       NaN
# 18                          None     0.00        0.00         0.00      0.00
# 19                           NaN      NaN         NaN          NaN       NaN
# 20                          None     0.00        0.00         0.00      0.00
# 21                           NaN      NaN         NaN          NaN       NaN
# 22                  Tax Subtotal   153.87       16.38         3.72     16.04
# 23                           NaN      NaN         NaN          NaN       NaN
# 24              Receipt Rounding     0.00        0.00         0.00      0.00
# 25                           NaN      NaN         NaN          NaN       NaN
# 26                Total of check  2110.87      289.38        85.72    279.94
# 27                           NaN      NaN         NaN          NaN       NaN
# 28
# 29                           NaN      NaN         NaN          NaN       NaN
# 30                 Tip collected   338.98       53.50        27.40     26.00
# 31                           NaN      NaN         NaN          NaN       NaN
# 32                   PaidIn - AR     0.00        0.00         0.00      0.00
# 33                           NaN      NaN         NaN          NaN       NaN
# 34              PaidIn - Debitek     0.00        0.00         0.00      0.00
# 35                           NaN      NaN         NaN          NaN       NaN
# 36    PaidIn - Gift Certificates     0.00        0.00         0.00      0.00
# 37                           NaN      NaN         NaN          NaN       NaN
# 38           Unadjusted receipts  2449.85      342.88       113.12    305.94
# 39                           NaN      NaN         NaN          NaN       NaN
# 40
# 41                           NaN      NaN         NaN          NaN       NaN
# 42                  No of Covers    65.00       12.00         4.00     43.00
# 43                           NaN      NaN         NaN          NaN       NaN
# 44                  No of Checks       66          12            4        43
# 45                           NaN      NaN         NaN          NaN       NaN
# 46                     Avg cover    30.11       22.75        20.50      6.14
# 47                           NaN      NaN         NaN          NaN       NaN
# 48                     Avg check    29.65       22.75        20.50      6.14
# 49                           NaN      NaN         NaN          NaN       NaN
# 50
# 51                           NaN      NaN         NaN          NaN       NaN
# 52                  ALL A&G CHRG    31.25       31.20         0.00      0.00
# 53                           NaN      NaN         NaN          NaN       NaN
# 54                   Room Charge   585.90      102.20        70.88     46.80
# 55                           NaN      NaN         NaN          NaN       NaN
# 56              American Express    91.79        0.00         0.00     10.22
# 57                           NaN      NaN         NaN          NaN       NaN
# 58                          Cash   240.84        0.00         0.00     35.60
# 59                           NaN      NaN         NaN          NaN       NaN
# 60                 Discover Card   134.73        0.00         0.00      0.00
# 61                           NaN      NaN         NaN          NaN       NaN
# 62                    MasterCard   334.45       58.32         0.00     31.38
# 63                           NaN      NaN         NaN          NaN       NaN
# 64                          Visa  1030.89      151.16        42.24    181.94
# 65                           NaN      NaN         NaN          NaN       NaN
# 66               $2 Tip - Coupon     0.00        0.00         0.00      0.00
# 67                           NaN      NaN         NaN          NaN       NaN
# 68                       PMS A&G     0.00        0.00         0.00      0.00
# 69                           NaN      NaN         NaN          NaN       NaN
# 70        Paper Gift Certificate     0.00        0.00         0.00      0.00
# 71                           NaN      NaN         NaN          NaN       NaN
# 72                       LevelUp     0.00        0.00         0.00      0.00
# 73                           NaN      NaN         NaN          NaN       NaN
# 74                         S & P     0.00        0.00         0.00      0.00
# 75                           NaN      NaN         NaN          NaN       NaN
# 76                  20% Discount     0.00        0.00         0.00      0.00
# 77                           NaN      NaN         NaN          NaN       NaN
# 78                   Bad Payment     0.00        0.00         0.00      0.00
# 79                           NaN      NaN         NaN          NaN       NaN
# 80              External Payment     0.00        0.00         0.00      0.00
# 81                           NaN      NaN         NaN          NaN       NaN
# 82
# 83                           NaN      NaN         NaN          NaN       NaN
# 84           Unadjusted receipts  2449.85      342.88       113.12    305.94
# 85                           NaN      NaN         NaN          NaN       NaN
# 86               Total Paid Outs     0.00        0.00         0.00      0.00
# 87                           NaN      NaN         NaN          NaN       NaN
# 88                   Server bank     0.00        0.00         0.00      0.00
# 89                           NaN      NaN         NaN          NaN       NaN
# 90                    Total tips   338.98       53.50        27.40     26.00
# 91                           NaN      NaN         NaN          NaN       NaN
# 92       Server credit card fees     0.00        0.00         0.00      0.00
# 93                           NaN      NaN         NaN          NaN       NaN
# 94                      Net tips   338.98       53.50        27.40     26.00
# 95                           NaN      NaN         NaN          NaN       NaN
# 96                      Net Cash   -98.14      -53.50       -27.40      9.60
# 97                           NaN      NaN         NaN          NaN       NaN
# 98      Other receipts turned in  2209.01      342.88       113.12    270.34
# 99                           NaN      NaN         NaN          NaN       NaN
# 100                 Server Drops     0.00        0.00         0.00      0.00
# 101                          NaN      NaN         NaN          NaN       NaN
# 102                    Turned in  2110.87      289.38        85.72    279.94
# 103                          NaN      NaN         NaN          NaN       NaN
# 104  Restaurant credit card fees     0.00        0.00         0.00      0.00
# 105                          NaN      NaN         NaN          NaN       NaN
# 106            Estimated deposit  2110.87      289.38        85.72    279.94
# 107                          NaN      NaN         NaN          NaN       NaN
# 108
# 109                          NaN      NaN         NaN          NaN       NaN
# 110          Beginning NRS Total     0.00        0.00         0.00      0.00
# 111                          NaN      NaN         NaN          NaN       NaN
# 112               Total Receipts  2449.85      342.88       113.12    305.94
# 113                          NaN      NaN         NaN          NaN       NaN
# 114                    Discounts     0.00        0.00         0.00      0.00
# 115                          NaN      NaN         NaN          NaN       NaN
# 116                     Paid Ins     0.00        0.00         0.00      0.00
# 117                          NaN      NaN         NaN          NaN       NaN
# 118                  Gross Total  2449.85      342.88       113.12    305.94
# 119                          NaN      NaN         NaN          NaN       NaN
# 120                    NRS Total  2449.85      342.88       113.12    305.94
# 121                          NaN      NaN         NaN          NaN       NaN
# 122                          NaN      NaN         NaN          NaN       NaN
# 123                          NaN      NaN         NaN          NaN       NaN
# 124                          NaN      NaN         NaN          NaN       NaN
# 125        *** End of Report ***      NaN         NaN          NaN       NaN

# %% [markdown]
# ---
#
# Now that I re-labeled the columns to match the data, I see there are blank rows between each row, similar to the blank columns experienced above.
#
# Knowing that the reports do not have any rows that are either missing values or completely blank, I will drop rows with any blank values.
#
# ---

# %%
## How many rows have missing values, and how many do they contain?

df.isna().sum(axis=1).value_counts()
# df.isna().sum(axis=0)
# Out:
# 5    64
# 0    61
# 4     1
# dtype: int64

# %%
## Displaying only rows without any missing values

df[df.isna().sum(axis=1) == 0]
# Out:
#                            Label      Bar Dining Room Room Service Starbucks
# 0                           Food   742.00      273.00        62.00    247.65
# 2                       Beverage  1215.00        0.00         0.00      0.00
# 4                          Other     0.00        0.00        20.00     16.25
# 6                 Sales Subtotal  1957.00      273.00        82.00    263.90
# 8                       Discount     0.00        0.00         0.00      0.00
# 10                        Charge     0.00        0.00         0.00      0.00
# 12              Total before tax  1957.00      273.00        82.00    263.90
# 14                    MD Food 6%    44.52       16.38         3.72     16.04
# 16                     MD Liq 9%   109.35        0.00         0.00      0.00
# 18                          None     0.00        0.00         0.00      0.00
# 20                          None     0.00        0.00         0.00      0.00
# 22                  Tax Subtotal   153.87       16.38         3.72     16.04
# 24              Receipt Rounding     0.00        0.00         0.00      0.00
# 26                Total of check  2110.87      289.38        85.72    279.94
# 28
# 30                 Tip collected   338.98       53.50        27.40     26.00
# 32                   PaidIn - AR     0.00        0.00         0.00      0.00
# 34              PaidIn - Debitek     0.00        0.00         0.00      0.00
# 36    PaidIn - Gift Certificates     0.00        0.00         0.00      0.00
# 38           Unadjusted receipts  2449.85      342.88       113.12    305.94
# 40
# 42                  No of Covers    65.00       12.00         4.00     43.00
# 44                  No of Checks       66          12            4        43
# 46                     Avg cover    30.11       22.75        20.50      6.14
# 48                     Avg check    29.65       22.75        20.50      6.14
# 50
# 52                  ALL A&G CHRG    31.25       31.20         0.00      0.00
# 54                   Room Charge   585.90      102.20        70.88     46.80
# 56              American Express    91.79        0.00         0.00     10.22
# 58                          Cash   240.84        0.00         0.00     35.60
# 60                 Discover Card   134.73        0.00         0.00      0.00
# 62                    MasterCard   334.45       58.32         0.00     31.38
# 64                          Visa  1030.89      151.16        42.24    181.94
# 66               $2 Tip - Coupon     0.00        0.00         0.00      0.00
# 68                       PMS A&G     0.00        0.00         0.00      0.00
# 70        Paper Gift Certificate     0.00        0.00         0.00      0.00
# 72                       LevelUp     0.00        0.00         0.00      0.00
# 74                         S & P     0.00        0.00         0.00      0.00
# 76                  20% Discount     0.00        0.00         0.00      0.00
# 78                   Bad Payment     0.00        0.00         0.00      0.00
# 80              External Payment     0.00        0.00         0.00      0.00
# 82
# 84           Unadjusted receipts  2449.85      342.88       113.12    305.94
# 86               Total Paid Outs     0.00        0.00         0.00      0.00
# 88                   Server bank     0.00        0.00         0.00      0.00
# 90                    Total tips   338.98       53.50        27.40     26.00
# 92       Server credit card fees     0.00        0.00         0.00      0.00
# 94                      Net tips   338.98       53.50        27.40     26.00
# 96                      Net Cash   -98.14      -53.50       -27.40      9.60
# 98      Other receipts turned in  2209.01      342.88       113.12    270.34
# 100                 Server Drops     0.00        0.00         0.00      0.00
# 102                    Turned in  2110.87      289.38        85.72    279.94
# 104  Restaurant credit card fees     0.00        0.00         0.00      0.00
# 106            Estimated deposit  2110.87      289.38        85.72    279.94
# 108
# 110          Beginning NRS Total     0.00        0.00         0.00      0.00
# 112               Total Receipts  2449.85      342.88       113.12    305.94
# 114                    Discounts     0.00        0.00         0.00      0.00
# 116                     Paid Ins     0.00        0.00         0.00      0.00
# 118                  Gross Total  2449.85      342.88       113.12    305.94
# 120                    NRS Total  2449.85      342.88       113.12    305.94

# %%
## Displaying only rows missing any values

# df[df.isna().sum(axis=1) > 0]
df[df.isna().sum(axis=1) > 0].value_counts(dropna=False)
# Out:
# Label                  Bar  Dining Room  Room Service  Starbucks
# NaN                    NaN  NaN          NaN           NaN          64
# *** End of Report ***  NaN  NaN          NaN           NaN           1
# dtype: int64

# %% [markdown]
# ---
#
# The simple filtering above confirms my assumption that rows missing any number of missing values do not contain any relevant information. In the normal printout, these rows would be blank spaces between lines.
#
# Additionally, I noticed there are a few rows that are "blank;" they contain some sort of data, but they do not provide meaningful information.
#
# I will filter out rows with missing values and blank rows.
#
# ---

# %%
## Checking size of dataframe prior to dropping rows
df.shape
# Out:
# (126, 5)

# %%
## Checking for blank rows
df['Label'].value_counts()
# Out:
#                                5
# None                           2
# Unadjusted receipts            2
# Food                           1
# Net tips                       1
# Paper Gift Certificate         1
# LevelUp                        1
# S & P                          1
# 20% Discount                   1
# Bad Payment                    1
# External Payment               1
# Total Paid Outs                1
# Server bank                    1
# Total tips                     1
# Server credit card fees        1
# Other receipts turned in       1
# Net Cash                       1
# $2 Tip - Coupon                1
# Server Drops                   1
# Turned in                      1
# Restaurant credit card fees    1
# Estimated deposit              1
# Beginning NRS Total            1
# Total Receipts                 1
# Discounts                      1
# Paid Ins                       1
# Gross Total                    1
# NRS Total                      1
# PMS A&G                        1
# MasterCard                     1
# Visa                           1
# Beverage                       1
# Other                          1
# Sales Subtotal                 1
# Discount                       1
# Charge                         1
# Total before tax               1
# MD Food 6%                     1
# MD Liq 9%                      1
# Tax Subtotal                   1
# Receipt Rounding               1
# Total of check                 1
# Tip collected                  1
# PaidIn - AR                    1
# PaidIn - Debitek               1
# PaidIn - Gift Certificates     1
# No of Covers                   1
# No of Checks                   1
# Avg cover                      1
# Avg check                      1
# ALL A&G CHRG                   1
# Room Charge                    1
# American Express               1
# Cash                           1
# Discover Card                  1
# *** End of Report ***          1
# Name: Label, dtype: int64

# %%
## Reviewing rows containing a blank space for a label
df[df.loc[:, "Label"].isin([' '])]
# Out:
#     Label Bar Dining Room Room Service Starbucks
# 28
# 40
# 50
# 82
# 108

# %%
## Filter out those rows with missing/blank values

df_cleaned = df[df.isna().sum(axis=1) == 0]
df_cleaned = df_cleaned[~df_cleaned.loc[:, "Label"].isin([' '])]
df_cleaned = df_cleaned.reset_index(drop=True)
df_cleaned
# Out:
#                           Label      Bar Dining Room Room Service Starbucks
# 0                          Food   742.00      273.00        62.00    247.65
# 1                      Beverage  1215.00        0.00         0.00      0.00
# 2                         Other     0.00        0.00        20.00     16.25
# 3                Sales Subtotal  1957.00      273.00        82.00    263.90
# 4                      Discount     0.00        0.00         0.00      0.00
# 5                        Charge     0.00        0.00         0.00      0.00
# 6              Total before tax  1957.00      273.00        82.00    263.90
# 7                    MD Food 6%    44.52       16.38         3.72     16.04
# 8                     MD Liq 9%   109.35        0.00         0.00      0.00
# 9                          None     0.00        0.00         0.00      0.00
# 10                         None     0.00        0.00         0.00      0.00
# 11                 Tax Subtotal   153.87       16.38         3.72     16.04
# 12             Receipt Rounding     0.00        0.00         0.00      0.00
# 13               Total of check  2110.87      289.38        85.72    279.94
# 14                Tip collected   338.98       53.50        27.40     26.00
# 15                  PaidIn - AR     0.00        0.00         0.00      0.00
# 16             PaidIn - Debitek     0.00        0.00         0.00      0.00
# 17   PaidIn - Gift Certificates     0.00        0.00         0.00      0.00
# 18          Unadjusted receipts  2449.85      342.88       113.12    305.94
# 19                 No of Covers    65.00       12.00         4.00     43.00
# 20                 No of Checks       66          12            4        43
# 21                    Avg cover    30.11       22.75        20.50      6.14
# 22                    Avg check    29.65       22.75        20.50      6.14
# 23                 ALL A&G CHRG    31.25       31.20         0.00      0.00
# 24                  Room Charge   585.90      102.20        70.88     46.80
# 25             American Express    91.79        0.00         0.00     10.22
# 26                         Cash   240.84        0.00         0.00     35.60
# 27                Discover Card   134.73        0.00         0.00      0.00
# 28                   MasterCard   334.45       58.32         0.00     31.38
# 29                         Visa  1030.89      151.16        42.24    181.94
# 30              $2 Tip - Coupon     0.00        0.00         0.00      0.00
# 31                      PMS A&G     0.00        0.00         0.00      0.00
# 32       Paper Gift Certificate     0.00        0.00         0.00      0.00
# 33                      LevelUp     0.00        0.00         0.00      0.00
# 34                        S & P     0.00        0.00         0.00      0.00
# 35                 20% Discount     0.00        0.00         0.00      0.00
# 36                  Bad Payment     0.00        0.00         0.00      0.00
# 37             External Payment     0.00        0.00         0.00      0.00
# 38          Unadjusted receipts  2449.85      342.88       113.12    305.94
# 39              Total Paid Outs     0.00        0.00         0.00      0.00
# 40                  Server bank     0.00        0.00         0.00      0.00
# 41                   Total tips   338.98       53.50        27.40     26.00
# 42      Server credit card fees     0.00        0.00         0.00      0.00
# 43                     Net tips   338.98       53.50        27.40     26.00
# 44                     Net Cash   -98.14      -53.50       -27.40      9.60
# 45     Other receipts turned in  2209.01      342.88       113.12    270.34
# 46                 Server Drops     0.00        0.00         0.00      0.00
# 47                    Turned in  2110.87      289.38        85.72    279.94
# 48  Restaurant credit card fees     0.00        0.00         0.00      0.00
# 49            Estimated deposit  2110.87      289.38        85.72    279.94
# 50          Beginning NRS Total     0.00        0.00         0.00      0.00
# 51               Total Receipts  2449.85      342.88       113.12    305.94
# 52                    Discounts     0.00        0.00         0.00      0.00
# 53                     Paid Ins     0.00        0.00         0.00      0.00
# 54                  Gross Total  2449.85      342.88       113.12    305.94
# 55                    NRS Total  2449.85      342.88       113.12    305.94

# %%
## Checking number of rows post-drop

df_cleaned.shape
# Out:
# (56, 5)

# %%
## Inspecting datatype and remaining data
df_cleaned.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 56 entries, 0 to 55
# Data columns (total 5 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Label         56 non-null     object
#  1   Bar           56 non-null     object
#  2   Dining Room   56 non-null     object
#  3   Room Service  56 non-null     object
#  4   Starbucks     56 non-null     object
# dtypes: object(5)
# memory usage: 2.3+ KB

# %% [markdown]
# ---
#
# **Review Current Status**
#
# At this point, I completed the following:
#
# - [X] Imported specified report data
# - [X] Removed blank columns and rows
# - [X] Removed any rows missing values
#
# At this point, I condensed the report and removed any extra spacing.
#
# **Now I need to decide which rows contain relevant data to keep and which rows contain extra data that we don't use.**
#
# ---
#
# **Keeping vs. Dropping**
#
# My original intention for this notebook/eventual script was to create a very minimalistic summary of the relevant day-to-day data, cutting out the extra stuff that we ignore.
# - This would provide me with the data specifically used during our night audit processes and remove any confusing extra details.
#
# However, I realized that approach would cause problems if/when we introduce new payment methods or would have any rare situations where relevant data would come through to the reports.
# - Missing such data could result in problems creating the daily reports or worse - obscure potential problems/irregularities.
#
# ---
#
# **Final Decision:**
#
# I will focus my code on keeping all row labels while maintaining a focus on the most important day-to-day details.
# - To address the concern about irregularities, I will create warnings to highlight such data.
#
# ---

# %% [markdown]
# # 🔨 Workflow

# %% [markdown]
# ---
#
# To create my ideal report, **I will focus on specific rows that I use most often for my reporting.**
#
# I will split the remaining rows into two groups:
# 1. Regularly-occurring (but irrelevant) data
#     - This includes subtotals and most of the rows at the end
#     - These rows are irrelevant for the day-to-day reports
#
#
# 2. Infrequent but highly valuable data
#     - This group would also act as a catch-all for any new rows, such as when we create a new payment method.
#
# **I will sub-divide the dataframe into the three new dataframes, one for each group.**
#
# - Both the "regular" data and "infrequent-but-valuable" dataframes will be included on the first sheet of the final Excel workbook
# - The extra dataframe will be saved to the second page.
#
# ---

# %%
## Create new DF

df_all_cols = df_cleaned.copy().T
df_all_cols
# Out:
#                   0         1      2               3         4       5   \
# Label           Food  Beverage  Other  Sales Subtotal  Discount  Charge
# Bar           742.00   1215.00   0.00         1957.00      0.00    0.00
# Dining Room   273.00      0.00   0.00          273.00      0.00    0.00
# Room Service   62.00      0.00  20.00           82.00      0.00    0.00
# Starbucks     247.65      0.00  16.25          263.90      0.00    0.00
#
#                             6           7          8     9   ...  \
# Label         Total before tax  MD Food 6%  MD Liq 9%  None  ...
# Bar                    1957.00       44.52     109.35  0.00  ...
# Dining Room             273.00       16.38       0.00  0.00  ...
# Room Service             82.00        3.72       0.00  0.00  ...
# Starbucks               263.90       16.04       0.00  0.00  ...
#
#                         46         47                           48  \
# Label         Server Drops  Turned in  Restaurant credit card fees
# Bar                   0.00    2110.87                         0.00
# Dining Room           0.00     289.38                         0.00
# Room Service          0.00      85.72                         0.00
# Starbucks             0.00     279.94                         0.00
#
#                              49                   50              51  \
# Label         Estimated deposit  Beginning NRS Total  Total Receipts
# Bar                     2110.87                 0.00         2449.85
# Dining Room              289.38                 0.00          342.88
# Room Service              85.72                 0.00          113.12
# Starbucks                279.94                 0.00          305.94
#
#                      52        53           54         55
# Label         Discounts  Paid Ins  Gross Total  NRS Total
# Bar                0.00      0.00      2449.85    2449.85
# Dining Room        0.00      0.00       342.88     342.88
# Room Service       0.00      0.00       113.12     113.12
# Starbucks          0.00      0.00       305.94     305.94
#
# [5 rows x 56 columns]

# %%
## Re-labeling columns based on "Label" row
df_all_cols.columns = df_all_cols.iloc[0]
df_all_cols = df_all_cols.drop(index = 'Label')
df_all_cols
# Out:
# Label           Food Beverage  Other Sales Subtotal Discount Charge  \
# Bar           742.00  1215.00   0.00        1957.00     0.00   0.00
# Dining Room   273.00     0.00   0.00         273.00     0.00   0.00
# Room Service   62.00     0.00  20.00          82.00     0.00   0.00
# Starbucks     247.65     0.00  16.25         263.90     0.00   0.00
#
# Label        Total before tax MD Food 6% MD Liq 9%  None  ... Server Drops  \
# Bar                   1957.00      44.52    109.35  0.00  ...         0.00
# Dining Room            273.00      16.38      0.00  0.00  ...         0.00
# Room Service            82.00       3.72      0.00  0.00  ...         0.00
# Starbucks              263.90      16.04      0.00  0.00  ...         0.00
#
# Label        Turned in Restaurant credit card fees Estimated deposit  \
# Bar            2110.87                        0.00           2110.87
# Dining Room     289.38                        0.00            289.38
# Room Service     85.72                        0.00             85.72
# Starbucks       279.94                        0.00            279.94
#
# Label        Beginning NRS Total Total Receipts Discounts Paid Ins  \
# Bar                         0.00        2449.85      0.00     0.00
# Dining Room                 0.00         342.88      0.00     0.00
# Room Service                0.00         113.12      0.00     0.00
# Starbucks                   0.00         305.94      0.00     0.00
#
# Label        Gross Total NRS Total
# Bar              2449.85   2449.85
# Dining Room       342.88    342.88
# Room Service      113.12    113.12
# Starbucks         305.94    305.94
#
# [4 rows x 56 columns]

# %%
## Specifying daily-use labels

daily_rows = ['Food', 'Beverage', 'Other', 'Discount', 'MD Food 6%',
              'MD Liq 9%', 'Tip collected', "ALL A&G CHRG", 'Room Charge',
              'American Express', 'Cash', 'Discover Card', 'MasterCard', 'Visa']

df_daily = df_all_cols[daily_rows]
df_daily
# Out:
# Label           Food Beverage  Other Discount MD Food 6% MD Liq 9%  \
# Bar           742.00  1215.00   0.00     0.00      44.52    109.35
# Dining Room   273.00     0.00   0.00     0.00      16.38      0.00
# Room Service   62.00     0.00  20.00     0.00       3.72      0.00
# Starbucks     247.65     0.00  16.25     0.00      16.04      0.00
#
# Label        Tip collected ALL A&G CHRG Room Charge American Express    Cash  \
# Bar                 338.98        31.25      585.90            91.79  240.84
# Dining Room          53.50        31.20      102.20             0.00    0.00
# Room Service         27.40         0.00       70.88             0.00    0.00
# Starbucks            26.00         0.00       46.80            10.22   35.60
#
# Label        Discover Card MasterCard     Visa
# Bar                 134.73     334.45  1030.89
# Dining Room           0.00      58.32   151.16
# Room Service          0.00       0.00    42.24
# Starbucks             0.00      31.38   181.94

# %%
## Converting data to "float"
for col in df_daily.columns:
    df_daily.loc[:,col] = pd.to_numeric(df_daily.loc[:,col], downcast = 'float')
    
df_daily
# Out:
# <ipython-input-20-04263d01f862>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_daily.loc[:,col] = pd.to_numeric(df_daily.loc[:,col], downcast = 'float')
# Label          Food  Beverage  Other  Discount  MD Food 6%  MD Liq 9%  \
# Bar          742.00   1215.00   0.00      0.00       44.52     109.35
# Dining Room  273.00      0.00   0.00      0.00       16.38       0.00
# Room Service  62.00      0.00  20.00      0.00        3.72       0.00
# Starbucks    247.65      0.00  16.25      0.00       16.04       0.00
#
# Label         Tip collected  ALL A&G CHRG  Room Charge  American Express  \
# Bar                  338.98         31.25       585.90             91.79
# Dining Room           53.50         31.20       102.20              0.00
# Room Service          27.40          0.00        70.88              0.00
# Starbucks             26.00          0.00        46.80             10.22
#
# Label          Cash  Discover Card  MasterCard    Visa
# Bar          240.84         134.73      334.45 1030.89
# Dining Room    0.00           0.00       58.32  151.16
# Room Service   0.00           0.00        0.00   42.24
# Starbucks     35.60           0.00       31.38  181.94

# %% [markdown]
# ## Creating Summary for Posting

# %% [markdown]
# ---
#
# **My main goal is to create a simple, easy-to-use report that I can roll-out quickly and easily.** Ideally, the summary will be intuitive, clear, and allow for the night auditor to post the charges quickly and easily.
#
# I know that there are only a select few columns that we reference for posting charges, so I will start my summary by creating a small dataframe summarizing the usual charges.
#
# ---

# %%
## Summarize food charges by outlet
daily_food = df_daily['Food'] + df_daily['Other'] - df_daily['Discount']
daily_food
# Out:
# Bar            742.00
# Dining Room    273.00
# Room Service    82.00
# Starbucks      263.90
# dtype: float32

# %%
## Summarize tax charges by outlet
daily_tax = df_daily['MD Food 6%']+df_daily['MD Liq 9%']
daily_tax
# Out:
# Bar            153.87
# Dining Room     16.38
# Room Service     3.72
# Starbucks       16.04
# dtype: float32

# %%
## Summarize all charges by outlet
summary = pd.concat([daily_food, df_daily['Beverage'], daily_tax, 
           df_daily['Tip collected']], axis=1)
summary
# Out:
#                   0  Beverage      1  Tip collected
# Bar          742.00   1215.00 153.87         338.98
# Dining Room  273.00      0.00  16.38          53.50
# Room Service  82.00      0.00   3.72          27.40
# Starbucks    263.90      0.00  16.04          26.00

# %%
## Creating new labels

col_labels = {0: "Food", 1: "Tax", 'Tip collected': 'Gratuity'}

row_labels = {'Bar': "Lobby Bar", "Dining Room": 'Rain 903', 
              'Room Service': 'In-Room Dining', 'Starbucks': 'Coffee Corner'}

col_labels, row_labels
# Out:
# ({0: 'Food', 1: 'Tax', 'Tip collected': 'Gratuity'},
#  {'Bar': 'Lobby Bar',
#   'Dining Room': 'Rain 903',
#   'Room Service': 'In-Room Dining',
#   'Starbucks': 'Coffee Corner'})

# %%
## Renaming columns
summary = summary.rename(columns = col_labels, index = row_labels)
summary
# Out:
#                  Food  Beverage    Tax  Gratuity
# Lobby Bar      742.00   1215.00 153.87    338.98
# Rain 903       273.00      0.00  16.38     53.50
# In-Room Dining  82.00      0.00   3.72     27.40
# Coffee Corner  263.90      0.00  16.04     26.00

# %%
## Rounding values - preventing long numbers
summary = summary.applymap(lambda x: round(x, 2))
summary
# Out:
#                  Food  Beverage    Tax  Gratuity
# Lobby Bar      742.00   1215.00 153.87    338.98
# Rain 903       273.00      0.00  16.38     53.50
# In-Room Dining  82.00      0.00   3.72     27.40
# Coffee Corner  263.90      0.00  16.04     26.00

# %%
## Saving results
# summary.to_excel('Test_Summary_Workbook.xlsx')

# %% [markdown]
# ## Summarizing the Summary

# %% [markdown]
# ---
#
# First summary working - need to expand
#
# * Repeat process per MOP
#     * A&G
#     * RC
#     * CA
#     * AX
#     * DI
#     * VI/MC
#
# * Save results to different sheets?
#
# ---

# %% [markdown]
# # 👨‍💻 So Far...

# %% [markdown]
# ---
#
# **√: MVP**
#
# - [x] Created function to clean, organize data from summary reports
#  - [x] Tested results by looping through list of files
#
#
# **TD: MVP**
#
#  - [ ] Add additional column identifying MOP
#  - [ ] Create multi-index w/ MOP, PC
#  - [ ] Concat DFs
#  - [ ] Save results to XL
#  - [ ] Convert to script
#
#
# **TD: AAB**
#
#  - [ ] Create filters to include extra details
#      * *Ex: Discounts, charges, any new MOPs, payments other than listed MOPs*
#
# ---

# %% [markdown]
# # ✔ Checkpoint - 4.19.22

# %% [markdown]
# ---
#
# **Current Status:**
#
# * Read Digital Dining report data *only for Excel files*
#     * AAB: read DBF files directly
#     * AAB: review sales type for discounts, subtract from proper sales type
#         * Currently subtracted from food generally
# * Clean the data to generate summaries about food/bev/tax/gratuity amounts
#     * MVP: confirm process works for all MOPs
# * Log warnings about any "Duplicate Check" or direct A&G postings
#
# ---
#
# **Next Steps:**
#
# 1. Test on most recent files
# 2. Artificially generate errors (then cancel before NA)
# 3. Condense into script to run on server
# 4. Test script
# 5. Schedule script to run daily
#
# ---

# %% [markdown]
# # 📄 Final Script

# %% [markdown]
# Two parts:
#
# 1. Run through workflow above using the overall summary data
# 2. Loop through a list of the usual MOPs and create a multi-indexed DataFrame containing the results for each outlet.

# %%
list_mops = ['ag', 'rc', 'ax', 'ca', 'di', 'vimc']

for mop in list_mops:
    
    workflow(data_filepath =f'./data/02_25_2022_mop_det_{mop}.xls', 
             receipts_filepath ='./data/april_2022_rc_receipts.xls',
             log_filepath = 'test_workflow_log.log',
             mop_name = mop)
